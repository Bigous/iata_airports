# %%
import numpy as np
import pandas as pd

# %%
# url = 'https://github.com/jpatokal/openflights/raw/master/data/airports.dat'
url = 'https://davidmegginson.github.io/ourairports-data/airports.csv'

df = pd.read_csv(url)

df
# Out:
#            id    ident           type                       name
# 0        6523      00A       heliport          Total Rf Heliport  \
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 75099   46378  ZZ-0001       heliport            Sealand Helipad
# 75100  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 75101  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 75102  342102     ZZZW         closed     Scandium City Heliport
# 75103  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country
# 0         40.070801     -74.933601          11.0       NaN          US  \
# ...

# %%
df['type'].unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
iata_airports = df[df["type"].isin(['small_airport', 'medium_airport', 'large_airport']) & df['iata_code'].notna()].copy()
iata_airports
# Out:
#            id ident            type                                     name
# 235      4650   03N   small_airport                           Utirik Airport  \
# 467      6924  07FA   small_airport                  Ocean Reef Club Airport
# 632      7063   0AK   small_airport                    Pilot Station Airport
# 711      7139  0CO2   small_airport                    Crested Butte Airpark
# 1136     7545  0TE7   small_airport                        LBJ Ranch Airport
# ...       ...   ...             ...                                      ...
# 75092   27242  ZYTL   large_airport  Dalian Zhoushuizi International Airport
# 75093  307013  ZYTN  medium_airport                Tonghua Sanyuanpu Airport
# 75094   27243  ZYTX   large_airport   Shenyang Taoxian International Airport
# 75096   27244  ZYYJ  medium_airport              Yanji Chaoyangchuan Airport
# 75097  317861  ZYYK  medium_airport                    Yingkou Lanqi Airport
#
# ...

# %%
from timezonefinder import TimezoneFinder
tf = TimezoneFinder()

# %%
tf.timezone_at(lat=-23.55,lng=-46.63)
# Out:
# 'America/Sao_Paulo'

# %%
iata_airports['timezone'] = iata_airports.apply(lambda row: tf.timezone_at(lat=row['latitude_deg'], lng=row['longitude_deg']), axis=1)
iata_airports
# Out:
#            id ident            type                                     name
# 235      4650   03N   small_airport                           Utirik Airport  \
# 467      6924  07FA   small_airport                  Ocean Reef Club Airport
# 632      7063   0AK   small_airport                    Pilot Station Airport
# 711      7139  0CO2   small_airport                    Crested Butte Airpark
# 1136     7545  0TE7   small_airport                        LBJ Ranch Airport
# ...       ...   ...             ...                                      ...
# 75092   27242  ZYTL   large_airport  Dalian Zhoushuizi International Airport
# 75093  307013  ZYTN  medium_airport                Tonghua Sanyuanpu Airport
# 75094   27243  ZYTX   large_airport   Shenyang Taoxian International Airport
# 75096   27244  ZYYJ  medium_airport              Yanji Chaoyangchuan Airport
# 75097  317861  ZYYK  medium_airport                    Yingkou Lanqi Airport
#
# ...

# %%
iata_airports.to_csv('iata_airports.csv')
